-- %% [markdown]
-- #### VALIDATE SLOWLY CHANGING DIMENSION
-- -- `NYCTAXI.SILVER.REGIONS_SCD_2`

-- %%
SELECT
*
FROM
NYCTAXI.SILVER.REGIONS_SCD_2
ORDER BY id ASC, effective_end_date DESC;

-- %%
%python
dbutils.notebook.exit('VALIDATION OF SLOWLY CHANGING DIMENSION NYCTAXI.SILVER.REGIONS_SCD_2-  IS SUCCESSFULL')
