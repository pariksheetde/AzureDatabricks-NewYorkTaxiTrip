-- %% [markdown]
-- #### VALIDATE `SILVER` LAYER

-- %%
-- VALIDATE `NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_CLEANSED`
SELECT
*
FROM
NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_CLEANSED
LIMIT 5;

-- %%
-- VALIDATE `NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_ENRICHED`
SELECT
*
FROM
NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_ENRICHED
LIMIT 15

-- %%
-- VALIDATE NYCTAXI.AUDIT.PIPELINE_EXECUTION_LOG
SELECT
TIMESTAMPDIFF(
           SECOND,
           load_start_time,
           load_end_time
       ) / 60.0 AS load_duration_minutes,
*
FROM
NYCTAXI.AUDIT.PIPELINE_EXECUTION_LOG
WHERE layer = 'SILVER'
AND target_table IN ('NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_CLEANSED','NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_ENRICHED', 'NYCTAXI.SILVER.REGIONS_SCD_2')

-- %%
%python
dbutils.notebook.exit('VALIDATION OF SILVER LAYER IS SUCCESSFULL')
