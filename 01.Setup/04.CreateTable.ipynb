-- %% [markdown]
-- #### CREATE TABLE FOR HANDLING SLOWLY CHANGING DIMENSION TYPE 2
-- - NYCTAXI.SILVER.REGIONS_SCD_2

-- %%
drop table  NYCTAXI.SILVER.REGIONS_SCD_2

-- %%
CREATE TABLE NYCTAXI.SILVER.REGIONS_SCD_2
(
ID INT,
name STRING,
effective_start_date TIMESTAMP,
effective_end_date TIMESTAMP,
load_timestamp TIMESTAMP
);
