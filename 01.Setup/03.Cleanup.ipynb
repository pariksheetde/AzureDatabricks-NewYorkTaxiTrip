-- %% [markdown]
-- #### DROP THE BRONZE TABLE
-- - NYCTAXI.BRONZE.TAXI_ZONE_LOOKUP
-- - NYCTAXI.BRONZE.YELLOW_TAXI

-- %%
DROP TABLE NYCTAXI.BRONZE.TAXI_ZONE_LOOKUP;
DROP TABLE NYCTAXI.BRONZE.YELLOW_TAXI;

-- %% [markdown]
-- #### DROP THE SILVER TABLE
-- - NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_CLEANSED

-- %%
DROP TABLE NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_CLEANSED;
DROP TABLE NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_ENRICHED;
