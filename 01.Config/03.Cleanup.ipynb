-- %% [markdown]
-- #### DROP `BRONZE` TABLE
-- - `NYCTAXI.BRONZE.YELLOW_TAXI`
-- - `NYCTAXI.BRONZE.TAXI_ZONE_LOOKUP`

-- %%
DROP TABLE IF EXISTS NYCTAXI.BRONZE.YELLOW_TAXI;
DROP TABLE IF EXISTS NYCTAXI.BRONZE.TAXI_ZONE_LOOKUP;

-- %% [markdown]
-- #### DROP `SILVER` TABLE
-- - `NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_CLEANSED`
-- - `NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_ENRICHED`
-- - `NYCTAXI.SILVER.REGIONS_SCD_2`

-- %%
DROP TABLE IF EXISTS NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_CLEANSED;
DROP TABLE IF EXISTS NYCTAXI.SILVER.YELLOW_TAXI_TRIPS_ENRICHED;
DROP TABLE IF EXISTS NYCTAXI.SILVER.REGIONS_SCD_2;

-- %% [markdown]
-- #### DROP `GOLD` LAYER

-- %%
DROP TABLE IF EXISTS NYCTAXI.GOLD.YELLOW_TAXI_DAILY_TRIP_SUMMARY

-- %% [markdown]
-- #### DROP AUDIT TABLE
-- - `NYTAXI.AUDIT.AUDIT_LOGS`

-- %%
DROP TABLE IF EXISTS NYCTAXI.AUDIT.AUDIT_LOGS;
